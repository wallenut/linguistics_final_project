# %%
# 6.1 Example: Learning XOR - GBC Book - Chapter 6 - pp. 166 to 171
# Some parts are inspired by the blog post
# Solving XOR with a Neural Network in TensorFlow
# by Stephen OMAN
# https://github.com/StephenOman/TensorFlowExamples/blob/master/xor%20nn/xor_nn.py

# Activation RELU + sigmoid for binary classification output + MSE loss function
import tensorflow as tf
import time
import numpy as np

# H is number of hidden units
H = 5

X = tf.placeholder(tf.float32, shape=[4,2], name = 'X')
Y = tf.placeholder(tf.float32, shape=[4,1], name = 'Y')

W = tf.Variable(tf.truncated_normal([2,H],stddev=.1), name = "W")
w = tf.Variable(tf.truncated_normal([H,1],stddev=.1), name = "w")

c = tf.Variable(tf.zeros([H]), name = "c")
b = tf.Variable(tf.zeros([1]), name = "b")

with tf.name_scope("hidden_layer") as scope:
    h = tf.nn.relu(tf.add(tf.matmul(X, W),c))

with tf.name_scope("output") as scope:
    y_estimated = tf.sigmoid(tf.add(tf.matmul(h,w),b))

with tf.name_scope("loss") as scope:
    loss = tf.reduce_mean(tf.squared_difference(y_estimated, Y)) 

# For better result with binary classifier, use cross entropy with a sigmoid
#    loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=y_estimated, labels=Y)

#Incorporating an L2 norm into the loss function
# regularizer = .01 * ( tf.nn.l2_loss(W) + tf.nn.l2_loss(w))


# A naïve direct implementation of the loss function
#     n_instances = X.get_shape().as_list()[0]
#     loss = tf.reduce_sum(tf.pow(y_estimated - Y, 2))/ n_instances

# In case of problem with gradient (exploding or vanishing gradient)perform gradient clipping
#     n_instances = X.get_shape().as_list()[0]
#     loss = tf.reduce_sum(tf.pow(tf.clip_by_value(y_estimated,1e-10,1.0) - Y,2))/(n_instances)

with tf.name_scope("train") as scope:
    train_step = tf.train.GradientDescentOptimizer(0.01).minimize(loss)

INPUT_XOR = [[0,0],[0,1],[1,0],[1,1]]
OUTPUT_XOR = [[0],[1],[1],[0]]
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    t_start = time.clock()
    for epoch in range(100001):
        sess.run(train_step, feed_dict={X: INPUT_XOR, Y: OUTPUT_XOR})
        if epoch % 10000 == 0:
            print("_"*80)
            print('Epoch: ', epoch)
            print('   y_estimated: ')
            for element in sess.run(y_estimated, feed_dict={X: INPUT_XOR, Y: OUTPUT_XOR}):
                print('    ',element)
            print('   w: ')
            for element in sess.run(w):
                print('    ',element)
            print('   b ')
            for element in sess.run(b):
                print('    ',element)
            print('   W: ')
            for element in sess.run(W):
                print('    ',element)
            print('   c: ')
            for element in sess.run(c):
                print('    ',element)
            print('   loss: ', sess.run(loss, feed_dict={X: INPUT_XOR, Y: OUTPUT_XOR}))
    t_end = time.clock()
    print("_"*80)
    print('Elapsed time ', t_end - t_start)
# Out:
# ________________________________________________________________________________
# ('Epoch: ', 0)
#    y_estimated:
# ('    ', array([ 0.50000209], dtype=float32))
# ('    ', array([ 0.50312966], dtype=float32))
# ('    ', array([ 0.50357848], dtype=float32))
# ('    ', array([ 0.50068295], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 0.11288327], dtype=float32))
# ('    ', array([ 0.16865432], dtype=float32))
# ('    ', array([-0.02655187], dtype=float32))
# ('    ', array([ 0.07728685], dtype=float32))
#    b
# ('    ', -9.2877817e-06)
#    W:
# ('    ', array([-0.0314922 ,  0.03919289, -0.10571464, -0.03876255,  0.12808494], dtype=float32))
# ('    ', array([-0.0981788 , -0.00032208,  0.10235868,  0.17900729, -0.10121072], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -6.0540157e-07)
# ('    ', 0.00010470759)
# ('    ', 1.270941e-07)
# ('    ', -4.1415913e-07)
# ('   loss: ', 0.24849999)
# ________________________________________________________________________________
# ('Epoch: ', 10000)
#    y_estimated:
# ('    ', array([ 0.19315033], dtype=float32))
# ('    ', array([ 0.87301928], dtype=float32))
# ('    ', array([ 0.87161416], dtype=float32))
# ('    ', array([ 0.18190528], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.0955981], dtype=float32))
# ('    ', array([ 2.19990206], dtype=float32))
# ('    ', array([-0.24724409], dtype=float32))
# ('    ', array([ 1.88192439], dtype=float32))
#    b
# ('    ', -1.3886402)
#    W:
# ('    ', array([-0.0314922 ,  0.77120066, -1.55491495,  0.04476045,  1.33479476], dtype=float32))
# ('    ', array([-0.0981788 , -0.7713241 ,  1.55478573,  0.25382456, -1.3349905 ], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -0.00010597008)
# ('    ', -1.32852e-05)
# ('    ', 0.16594315)
# ('    ', -0.00039902961)
# ('   loss: ', 0.025750903)
# ________________________________________________________________________________
# ('Epoch: ', 20000)
#    y_estimated:
# ('    ', array([ 0.09141044], dtype=float32))
# ('    ', array([ 0.9441337], dtype=float32))
# ('    ', array([ 0.94453752], dtype=float32))
# ('    ', array([ 0.07180489], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.36338174], dtype=float32))
# ('    ', array([ 2.7410605], dtype=float32))
# ('    ', array([-0.53624511], dtype=float32))
# ('    ', array([ 2.3450563], dtype=float32))
#    b
# ('    ', -2.0699062)
#    W:
# ('    ', array([-0.0314922 ,  0.96130484, -1.93769157,  0.14073128,  1.66157246], dtype=float32))
# ('    ', array([-0.0981788 , -0.96131587,  1.93767738,  0.34926075, -1.66160214], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -2.7019405e-05)
# ('    ', -5.9107348e-05)
# ('    ', 0.42261928)
# ('    ', -3.4229146e-05)
# ('   loss: ', 0.0049272352)
# ________________________________________________________________________________
# ('Epoch: ', 30000)
#    y_estimated:
# ('    ', array([ 0.06500902], dtype=float32))
# ('    ', array([ 0.96130234], dtype=float32))
# ('    ', array([ 0.96157026], dtype=float32))
# ('    ', array([ 0.04577144], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.46342719], dtype=float32))
# ('    ', array([ 2.94564819], dtype=float32))
# ('    ', array([-0.67170095], dtype=float32))
# ('    ', array([ 2.517941], dtype=float32))
#    b
# ('    ', -2.2922151)
#    W:
# ('    ', array([-0.0314922 ,  1.03224933, -2.08238602,  0.17254098,  1.78362417], dtype=float32))
# ('    ', array([-0.0981788 , -1.03223097,  2.08239841,  0.38021532, -1.78359687], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -9.2738028e-06)
# ('    ', -3.4295575e-05)
# ('    ', 0.55649137)
# ('    ', -1.0784121e-05)
# ('   loss: ', 0.0023238878)
# ________________________________________________________________________________
# ('Epoch: ', 40000)
#    y_estimated:
# ('    ', array([ 0.05223659], dtype=float32))
# ('    ', array([ 0.96934235], dtype=float32))
# ('    ', array([ 0.9695226], dtype=float32))
# ('    ', array([ 0.03437921], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.52266991], dtype=float32))
# ('    ', array([ 3.0667212], dtype=float32))
# ('    ', array([-0.75464505], dtype=float32))
# ('    ', array([ 2.6202879], dtype=float32))
#    b
# ('    ', -2.4132736)
#    W:
# ('    ', array([-0.0314922 ,  1.0742259 , -2.16801095,  0.1860054 ,  1.8558619 ], dtype=float32))
# ('    ', array([-0.0981788 , -1.07423711,  2.16803432,  0.39316663, -1.85586524], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -1.8755827e-05)
# ('    ', 3.4200166e-06)
# ('    ', 0.64276367)
# ('    ', -1.4613477e-05)
# ('   loss: ', 0.0014448387)
# ________________________________________________________________________________
# ('Epoch: ', 50000)
#    y_estimated:
# ('    ', array([ 0.04446997], dtype=float32))
# ('    ', array([ 0.97411716], dtype=float32))
# ('    ', array([ 0.97425508], dtype=float32))
# ('    ', array([ 0.02795153], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.56405461], dtype=float32))
# ('    ', array([ 3.1512351], dtype=float32))
# ('    ', array([-0.81343859], dtype=float32))
# ('    ', array([ 2.69179296], dtype=float32))
#    b
# ('    ', -2.4934762)
#    W:
# ('    ', array([-0.0314922 ,  1.1035651 , -2.22777963,  0.19258267,  1.906353  ], dtype=float32))
# ('    ', array([-0.0981788 , -1.10356212,  2.22779584,  0.3994076 , -1.90634656], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', 5.1357347e-08)
# ('    ', -2.2361137e-06)
# ('    ', 0.7056216)
# ('    ', 1.4810425e-06)
# ('   loss: ', 0.0010228972)
# ________________________________________________________________________________
# ('Epoch: ', 60000)
#    y_estimated:
# ('    ', array([ 0.03915431], dtype=float32))
# ('    ', array([ 0.97732645], dtype=float32))
# ('    ', array([ 0.97744179], dtype=float32))
# ('    ', array([ 0.02379503], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.59560633], dtype=float32))
# ('    ', array([ 3.21549153], dtype=float32))
# ('    ', array([-0.85863262], dtype=float32))
# ('    ', array([ 2.74625444], dtype=float32))
#    b
# ('    ', -2.552259)
#    W:
# ('    ', array([-0.0314922 ,  1.12591004, -2.27326012,  0.19596663,  1.94480121], dtype=float32))
# ('    ', array([-0.0981788 , -1.12590098,  2.27325678,  0.40254444, -1.94479692], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -3.4285836e-06)
# ('    ', -2.3205588e-05)
# ('    ', 0.75474)
# ('    ', -5.4389907e-06)
# ('   loss: ', 0.00078055658)
# ________________________________________________________________________________
# ('Epoch: ', 70000)
#    y_estimated:
# ('    ', array([ 0.03524626], dtype=float32))
# ('    ', array([ 0.97966707], dtype=float32))
# ('    ', array([ 0.97976238], dtype=float32))
# ('    ', array([ 0.02087433], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.62090361], dtype=float32))
# ('    ', array([ 3.26712656], dtype=float32))
# ('    ', array([-0.8951695], dtype=float32))
# ('    ', array([ 2.79000378], dtype=float32))
#    b
# ('    ', -2.5979705)
#    W:
# ('    ', array([-0.0314922 ,  1.14384425, -2.30974007,  0.19766672,  1.97568417], dtype=float32))
# ('    ', array([-0.0981788 , -1.14384627,  2.30974054,  0.40405229, -1.97567904], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -1.1031435e-06)
# ('    ', -7.7480754e-06)
# ('    ', 0.79488212)
# ('    ', 4.0522482e-06)
# ('   loss: ', 0.00062525662)
# ________________________________________________________________________________
# ('Epoch: ', 80000)
#    y_estimated:
# ('    ', array([ 0.03222426], dtype=float32))
# ('    ', array([ 0.98146051], dtype=float32))
# ('    ', array([ 0.98153496], dtype=float32))
# ('    ', array([ 0.01869739], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.64197946], dtype=float32))
# ('    ', array([ 3.31007576], dtype=float32))
# ('    ', array([-0.92575377], dtype=float32))
# ('    ', array([ 2.8263247], dtype=float32))
#    b
# ('    ', -2.6351068)
#    W:
# ('    ', array([-0.0314922 ,  1.15876436, -2.34012651,  0.1983988 ,  2.00137687], dtype=float32))
# ('    ', array([-0.0981788 , -1.15876043,  2.34013128,  0.4046354 , -2.00136423], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', 7.3232081e-07)
# ('    ', 2.7513333e-06)
# ('    ', 0.82871318)
# ('    ', -4.5607758e-06)
# ('   loss: ', 0.00051816646)
# ________________________________________________________________________________
# ('Epoch: ', 90000)
#    y_estimated:
# ('    ', array([ 0.02980444], dtype=float32))
# ('    ', array([ 0.98288018], dtype=float32))
# ('    ', array([ 0.98295158], dtype=float32))
# ('    ', array([ 0.01700504], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.65994823], dtype=float32))
# ('    ', array([ 3.34665465], dtype=float32))
# ('    ', array([-0.95199639], dtype=float32))
# ('    ', array([ 2.85738492], dtype=float32))
#    b
# ('    ', -2.6661472)
#    W:
# ('    ', array([-0.0314922 ,  1.17154372, -2.36605191,  0.19854629,  2.02340913], dtype=float32))
# ('    ', array([-0.0981788 , -1.17153871,  2.36604881,  0.40467322, -2.02340817], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', -1.3480799e-06)
# ('    ', -6.9769266e-07)
# ('    ', 0.85788536)
# ('    ', 3.7424543e-06)
# ('   loss: ', 0.00044030329)
# ________________________________________________________________________________
# ('Epoch: ', 100000)
#    y_estimated:
# ('    ', array([ 0.02781166], dtype=float32))
# ('    ', array([ 0.98404747], dtype=float32))
# ('    ', array([ 0.98410147], dtype=float32))
# ('    ', array([ 0.01564801], dtype=float32))
#    w:
# ('    ', array([ 0.03306176], dtype=float32))
# ('    ', array([ 1.67566633], dtype=float32))
# ('    ', array([ 3.37866211], dtype=float32))
# ('    ', array([-0.9749248], dtype=float32))
# ('    ', array([ 2.88454032], dtype=float32))
#    b
# ('    ', -2.6927712)
#    W:
# ('    ', array([-0.0314922 ,  1.18260288, -2.38863564,  0.19831625,  2.04237199], dtype=float32))
# ('    ', array([-0.0981788 , -1.18260014,  2.38863373,  0.40434554, -2.04237008], dtype=float32))
#    c:
# ('    ', 0.0)
# ('    ', 1.2123314e-07)
# ('    ', -8.5905294e-06)
# ('    ', 0.88347661)
# ('    ', -3.2285673e-06)
# ('   loss: ', 0.00038139871)
# ________________________________________________________________________________
# ('Elapsed time ', 85.84839)
